# %% [markdown]
# #### Exercise 1

# %% [markdown]
# In the code below, which will never print regardless of the value for x? Edit the code to correct the error.
#
# ```python
# if x > 0 :
#     print('Above 0')
# elif x >  10 :
#     print('Above 10')
# elif x > 50 :
#     print('Above 50')
# elif x >  20 :
#     print('Above 20')
# else :
#     print('Something else')
# ```

# %%
x = int(input("Enter a value for x: "))

if x > 0 :
    print('Above 0')
elif x >  10 :
    print('Above 10')
elif x > 20 :
    print('Above 20')
elif x >  50 :
    print('Above 5 0')
else :
    print('Something else')
# Out:
# Enter a value for x: 5
# Above 0

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Write your salary computation to give an employee 1.5 times the hourly rate for hours worked above 40 hours. Example:
#
#     Enter Hours: 45
#     Enter Rate: 10
#     Pay: 475.0
#
# [PEW] E3.2

# %%
hours_worked = float(input("Enter Hours: "))
hour_rate = float(input("Enter Rate: "))

if hours_worked <= 40:
    pay = hours_worked * hour_rate
else:
    initial_pay = 40 * hour_rate
    overtime_hours = hours_worked - 40
    overtime_pay = overtime_hours * 1.5 * hour_rate
    pay = initial_pay + overtime_pay

print("Pay:", pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# Write a program to prompt for a score between 0 and 100 and print a grade using the following table:
#
#     Score           Grade
#     [ 97, 100]      1.0
#     [ 93,  97)		1.25
#     [ 89,  93)		1.5
#     [ 85,  89)		1.75
#     [ 81,  85)		2.0
#     [ 77,  81)		2.25
#     [ 74,  77)		2.5
#     [ 0,   74)		3.0
#
# Adapted from [PEW] E3.3
# <br>

# %%
score = int(input("Enter a score between 0 and 100: "))

if 97 <= score <= 100:
    grade = 1.0
elif 93 <= score < 97:
    grade = 1.25
elif 89 <= score < 93:
    grade = 1.5
elif 85 <= score < 89:
    grade = 1.75
elif 81 <= score < 85:
    grade = 2.0
elif 77 <= score < 81:
    grade = 2.25
elif 74 <= score < 77:
    grade = 2.5
elif 0 <= score < 74:
    grade = 3.0
else:
    grade = "Invalid score"

print("Grade:", grade)
# Out:
# Enter a score between 0 and 100: 79
# Grade: 2.25
